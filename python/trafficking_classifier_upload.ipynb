# %% [markdown]
# # Trafficking classifier
#
# This notebook contains the code for classifying the extracted trafficking relationships between pairs of countries. Countries are classified as either senders or recievers.
#
# Implemented by Mitchell Goist and Christopher Boylan

# %%
import pandas as pd
import numpy as np
import glob
import os
from collections import Counter
from bs4 import BeautifulSoup
import re
# matplotlib
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf
# seaborn
import seaborn as sns
# Scikit-learn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import GridSearchCV, train_test_split, KFold, cross_val_predict
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB, BernoulliNB
from sklearn.svm import SVC
from sklearn.preprocessing import label_binarize
from sklearn.metrics import accuracy_score, classification_report, f1_score, make_scorer, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier
# %matplotlib inline
plt.rcParams["axes.labelsize"] = 15
plt.rcParams["ytick.labelsize"] = 'large'

# %%
def supervisor(text):
    sentences = text.split('.')
    source = sentences[0].find('source') > -1
    destination = sentences[0].find('destination') > -1
    transit = sentences[0].find('transit') > -1
    if source and not destination and not transit:
        label = 0
    elif destination and not source and not transit:
        label = 1
    else:
        label = ' '
    return label

# %% [markdown]
# ### Prepare the data for classifiers

# %%
# Clean up hand-coding
mitch = pd.read_csv('../relation_extracction/annotation/mitch_coding.csv',
                    index_col=0)
chris = pd.read_csv('../relation_extracction/annotation/christopher_coding.csv',
                   index_col=0)
hand_codes = pd.concat([mitch, chris])

# %%
sentences = pd.read_csv('extracted_entities_dictionary_sents_v2.csv')

# %%
# Remove duplicate sentences to prevent extra rows from being created in the merge
clean_training = hand_codes.drop_duplicates(subset='text')
clean_training = clean_training[['file', 'text', 'label']]
clean_training['label'] = pd.to_numeric(clean_training['label'], errors='coerce')
clean_training
# Out:
#                                       file  \
# 3901                     ../2011/Sudan.txt
# 1002               ../2005/Switzerland.txt
# 1827                     ../2008/Chile.txt
# 4419                   ../2012/Morocco.txt
# 905                      ../2005/Kenya.txt
# 7678                     ../2016/Sudan.txt
# 379            ../2003/Kyrgyz_Republic.txt
# 1739                  ../2007/Zimbabwe.txt
# 33                  ../2001/Costa_Rica.txt
# 1637                    ../2007/Russia.txt
# 6977                     ../2015/Syria.txt
# 3413                   ../2011/Armenia.txt
# 2995                 ../2010/Guatemala.txt
# 7530                ../2016/Mozambique.txt
# 4581                 ../2012/Swaziland.txt
# 4592                     ../2012/Syria.txt
# 1340          ../2006/The_Netherlands1.txt
# 3349                   ../2010/Uruguay.txt
# 332                      ../2003/China.txt
# 3500                     ../2011/China.txt
# 4708                    ../2012/Zambia.txt
# 7176                    ../2016/Brazil.txt
# 5085                   ../2013/Lesotho.txt
# 7403                     ../2016/Italy.txt
# 6655                      ../2015/Iraq.txt
# 7445                      ../2016/Laos.txt
# 5330               ../2013/South_Sudan.txt
# 2112                  ../2008/Suriname.txt
# 6780                 ../2015/Mauritius.txt
# 3810                    ../2011/Norway.txt
# ...                                    ...
# 310                 ../2003/Bangladesh.txt
# 909            ../2005/Kyrgyz_Republic.txt
# 7814                    ../2016/Zambia.txt
# 1945                     ../2008/Japan.txt
# 4672  ../2012/United_States_Of_America.txt
# 4012                     ../2011/Yemen.txt
# 2111                  ../2008/Suriname.txt
# 6710                      ../2015/Laos.txt
# 1727                   ../2007/Vietnam.txt
# 1051                  ../2005/Zimbabwe.txt
# 6468                  ../2015/Bulgaria.txt
# 5951                     ../2014/Libya.txt
# 3596                 ../2011/Hong_Kong.txt
# 644                     ../2004/Malawi.txt
# 1080                    ../2006/Belize.txt
# 1713                   ../2007/Ukraine.txt
# 2143                  ../2008/Thailand.txt
# 4166        ../2012/Dominican_Republic.txt
# 4534              ../2012/Sierra_Leone.txt
# 3869                  ../2011/Slovenia.txt
# 1656                  ../2007/Slovenia.txt
# 7059             ../2015/United_States.txt
# 4495          ../2012/Papua_New_Guinea.txt
# 6143                   ../2014/Senegal.txt
# 6924                   ../2015/Somalia.txt
# 3373                    ../2010/Zambia.txt
# 2975                     ../2010/Gabon.txt
# 3499                     ../2011/Chile.txt
# 1271                  ../2006/Paraguay.txt
# 5776                    ../2014/Greece.txt
#
#                                                    text  label
# 3901  FILIPINA MIGRANT DOMESTIC WORKERS MAY ALSO BE ...    1.0
# 1002  \n\nSWITZERLAND IS PRIMARILY A DESTINATION COU...    1.0
# 1827  MIGRANTS FROM PERU AND BOLIVIA, INCLUDING CHIL...    1.0
# 4419  MOROCCAN WOMEN ARE FORCED INTO PROSTITUTION IN...    0.0
# 905   ASIAN NATIONALS, MAINLY CHINESE WOMEN, ARE REP...    1.0
# 7678  SOME SUDANESE CITIZENS WHO MIGRATE TO EUROPE V...    0.0
# 379   MEN AND WOMEN ARE TRAFFICKED TO KAZAKHSTAN FOR...    0.0
# 1739  YOUNG WOMEN AND GIRLS ARE ALSO LURED TO SOUTH ...    0.0
# 33    THERE ALSO HAVE BEEN REPORTS OF GIRLS FROM THE...    1.0
# 1637  RUSSIA IS A SOURCE COUNTRY FOR MEN AND WOMEN T...    0.0
# 6977  THE MEDIA REPORTED INSTANCES IN WHICH THE IRAN...    0.0
# 3413  ARMENIAN MEN AND WOMEN ARE SUBJECTED TO FORCED...    0.0
# 2995  THE BORDER WITH MEXICO REMAINS A TOP CONCERN D...    0.0
# 7530  INFORMAL NETWORKS TYPICALLY COMPRISE MOZAMBICA...    NaN
# 4581  SOME SWAZI WOMEN ARE FORCED INTO PROSTITUTION ...    0.0
# 4592  AT THE END OF THE REPORTING PERIOD, MEDIA REPO...    1.0
# 1340  VICTIMS CONTINUED TO BE TRAFFICKED FROM CENTRA...    1.0
# 3349  LURED BY FRAUDULENT RECRUITMENT OFFERS, SOME U...    0.0
# 332   CHINESE ARE TRAFFICKED TO TAIWAN, SINGAPORE, A...    0.0
# 3500  WOMEN AND CHILDREN FROM NEIGHBORING COUNTRIES ...    1.0
# 4708  AN INCREASING NUMBER OF CHINESE AND INDIAN MEN...    1.0
# 7176  BRAZILIAN WOMEN ARE FOUND IN SEX TRAFFICKING A...    0.0
# 5085  DURING THE YEAR, A BASOTHO TRAFFICKING VICTIM ...    0.0
# 7403  EASTERN EUROPEAN WOMEN AND GIRLS ARE FORCED IN...    1.0
# 6655  SOME SYRIAN REFUGEE MEN ENTER INTO EMPLOYMENT ...    1.0
# 7445  NGOS REPORT INDIVIDUALS OFFERING TRANSPORTATIO...    0.0
# 5330  SOME GOVERNMENT OFFICIALS, INCLUDING MEMBERS O...    NaN
# 2112  CHINESE WOMEN REPORTEDLY ARE EXPLOITED SEXUALL...    1.0
# 6780  IN RECENT YEARS, SMALL NUMBERS OF MAURITIAN AD...    0.0
# 3810  THESE VICTIMS USUALLY TRAVEL TO NORWAY ON SCHE...    1.0
# ...                                                 ...    ...
# 310   BOYS ARE ALSO TRAFFICKED TO THE UNITED ARAB EM...    0.0
# 909   KYRGYZ WOMEN AND GIRLS ARE TRAFFICKED FOR THE ...    0.0
# 7814  CHINESE TRAFFICKERS BRING IN CHINESE WOMEN AND...    1.0
# 1945  WOMEN AND CHILDREN TRAFFICKED TO JAPAN FOR COM...    1.0
# 4672  THE FIRST CIVIL RIGHTS CONFERENCE, WHICH INCLU...    NaN
# 4012  TO A LESSER EXTENT, YEMEN IS ALSO A SOURCE COU...    0.0
# 2111  CHINESE MEN ARE SUBJECTED TO POSSIBLE DEBT BON...    1.0
# 6710  LAO VICTIMS OF FORCED LABOR IN THE THAI FISHIN...    0.0
# 1727  VIETNAMESE WOMEN AND GIRLS ARE TRAFFICKED TO C...    0.0
# 1051  THERE WERE UNCONFIRMED REPORTS THAT TRAFFICKIN...    0.0
# 6468  ROMANIAN GIRLS ARE SUBJECTED TO SEX TRAFFICKIN...    1.0
# 5951  SOME NIGERIAN WOMEN ARE REPORTEDLY FORCED INTO...    1.0
# 3596  \nTHE HONG KONG SPECIAL ADMINISTRATIVE REGION ...    1.0
# 644   ZAMBIAN WOMEN ARE REPORTEDLY TRAFFICKED FOR FO...    1.0
# 1080  THERE ARE ALSO UNCONFIRMED REPORTS THAT INDIAN...    1.0
# 1713  WOMEN FROM CENTRAL ASIAN COUNTRIES SUCH AS UZB...    1.0
# 2143  SOME THAI MEN WHO MIGRATE FOR LOW-SKILLED CONT...    0.0
# 4166  STREET CHILDREN AND THE LARGE POPULATION OF UN...    1.0
# 4534  SIERRA LEONEANS VOLUNTARILY MIGRATE TO OTHER W...    0.0
# 3869  WOMEN AND CHILDREN FROM SLOVENIA, AS WELL AS U...    NaN
# 1656  GIRLS WERE TRAFFICKED TO SLOVENIA FROM BOSNIA ...    0.0
# 7059  DOD ISSUED A NEW POLICY PROHIBITING U.S. MILIT...    NaN
# 4495  FILIPINO MEN, BROUGHT INTO THE COUNTRY WITHOUT...    1.0
# 6143  INTERNAL TRAFFICKING IS MORE PREVALENT THAN TR...    1.0
# 6924  AUTHORITIES IN SOMALILAND REPORT AN INCREASE I...    0.0
# 3373  AFTER WORK HOURS, SOME CHINESE MINERS ARE CONF...    1.0
# 2975  STEPPED-UP COASTAL SURVEILLANCE OVER THE PAST ...    NaN
# 3499  THERE ARE REPORTS THAT CHILDREN ARE RECRUITED ...    0.0
# 1271  THIS TRANSNATIONAL TRAFFICKING APPEARS TO BE I...    1.0
# 5776  SOME WOMEN FROM EASTERN EUROPE (INCLUDING LATV...    1.0
#
# [1118 rows x 3 columns]

# %%
def supervisor(text):
    sentences = text.split('.')
    source = sentences[0].find('source') > -1
    destination = sentences[0].find('destination') > -1
    transit = sentences[0].find('transit') > -1
    if source and not destination and not transit:
        label = 0
    elif destination and not source and not transit:
        label = 1
    else:
        label = ' '
    return label
#add automatic labels
labels = []
fnames = []
for year in range(2001, 2016+1):
    for doc in glob.glob('../'+str(year)+'/*.txt'):
        #print(doc)
        contents=open(doc).read()
        fnames.append(doc)
        labels.append(supervisor(contents))
        

lazy_supervision = pd.DataFrame({'file' : fnames,
                              'label' : labels})

# %%
temp = sentences.merge(lazy_supervision, on=['file'], how='left')
temp['label'] = pd.to_numeric(temp['label'], errors='coerce')

# %%
combined = temp.merge(clean_training, on=['file', 'text'], how='left')

# %%
combined.shape
combined['label'] = combined['label_x']
combined
# Out:
#                                               countries             country  \
# 0      ROMANIA;NETHERLANDS;ITALY;MOLDOVA;GREECE;BELGIUM             ALBANIA
# 1     UKRAINE;ROMANIA;CZECH REPUBLIC;SLOVAKIA;HUNGAR...             AUSTRIA
# 2     RUSSIAN FEDERATION;ETHIOPIA;PHILIPPINES;BELARU...             BAHRAIN
# 3                                        PAKISTAN;INDIA          BANGLADESH
# 4     UKRAINE;GERMANY;POLAND;LITHUANIA;RUSSIAN FEDER...             BELARUS
# 5                                 NIGERIA;ALBANIA;CHINA             BELGIUM
# 6                                                 CHINA             BELGIUM
# 7                                   GHANA;NIGERIA;GABON               BENIN
# 8                               TOGO;NIGER;BURKINA FASO               BENIN
# 9        UKRAINE;ROMANIA;BOSNIA AND HERZEGOVINA;MOLDOVA  BOSNIA-HERZEGOVINA
# 10                               BOSNIA AND HERZEGOVINA  BOSNIA-HERZEGOVINA
# 11                               BOSNIA AND HERZEGOVINA  BOSNIA-HERZEGOVINA
# 12                               BOSNIA AND HERZEGOVINA  BOSNIA-HERZEGOVINA
# 13                               BOSNIA AND HERZEGOVINA  BOSNIA-HERZEGOVINA
# 14                JAPAN;ISRAEL;UNITED STATES OF AMERICA              BRAZIL
# 15    UKRAINE;TURKEY;ROMANIA;GEORGIA;ITALY;KOSOVO;PO...            BULGARIA
# 16                                                 MALI        BURKINA FASO
# 17                                   COTE D'IVOIRE;MALI        BURKINA FASO
# 18                                                 MALI        BURKINA FASO
# 19                          GHANA;NIGERIA;COTE D'IVOIRE        BURKINA FASO
# 20                                              GERMANY        BURKINA FASO
# 21                                             THAILAND             MYANMAR
# 22                                             THAILAND             MYANMAR
# 23       SINGAPORE;MALAYSIA;CHINA;THAILAND;JAPAN;TAIWAN             MYANMAR
# 24                                             THAILAND            CAMBODIA
# 25                                              VIETNAM            CAMBODIA
# 26          THAILAND;AUSTRALIA;UNITED STATES OF AMERICA            CAMBODIA
# 27                    RUSSIAN FEDERATION;HONDURAS;CHINA              CANADA
# 28                             UNITED STATES OF AMERICA              CANADA
# 29    AUSTRALIA;MYANMAR;PHILIPPINES;MALAYSIA;JAPAN;T...               CHINA
# ...                                                 ...                 ...
# 24                                             THAILAND
# 25                                              VIETNAM
# 26                     AUSTRALIA;THAILAND;UNITED STATES
# 27                                CHINA;RUSSIA;HONDURAS
# 28                                        UNITED STATES
# 29    AUSTRALIA;JAPAN;BURMA;MALAYSIA;THE PHILIPPINES...
# ...                                                 ...
# 7796  JAPAN;LAOS;MALAYSIA;UNITED ARAB EMIRATES;ANGOL...
# 7797  SINGAPORE;THAILAND;CAMBODIA;LAOS;MALAYSIA;CHIN...
# 7798                           SINGAPORE;MALAYSIA;CHINA
# 7799                                     UNITED KINGDOM
# 7800                                              SAUDI
# 7801                                         SAUDI;OMAN
# 7802                                              SAUDI
# 7803                                              SAUDI
# 7804                                             SYRIAN
# 7805                                             SYRIAN
# 7806                                              SAUDI
# 7807                                              SAUDI
# 7808                                              SAUDI
# 7809                                              SAUDI
# 7810                                              SAUDI
# 7811                               ZIMBABWEAN;TANZANIAN
# 7812                              ZIMBABWE;SOUTH AFRICA
# 7813                                            CHINESE
# 7814                                            CHINESE
# 7815                         SOUTH AFRICAN;SOUTH AFRICA
# 7816    DEMOCRATIC REPUBLIC OF THE CONGO;ETHIOPIA;SYRIA
# 7817                     ZAMBIA;MOZAMBIQUE;SOUTH AFRICA
# 7818                                              CHINA
# 7819                                         MOZAMBIQUE
# 7820                                       SOUTH AFRICA
# 7821                                       SOUTH AFRICA
# 7822                                       SOUTH AFRICA
# 7823           DEMOCRATIC REPUBLIC OF THE CONGO;SOMALIA
# 7824                                            CHINESE
# 7825                                            CHINESE
#
#                                 file  \
# 0                ../2001/Albania.txt
# 1                ../2001/Austria.txt
# 2                ../2001/Bahrain.txt
# 3             ../2001/Bangladesh.txt
# 4                ../2001/Belarus.txt
# 5                ../2001/Belgium.txt
# 6                ../2001/Belgium.txt
# 7                  ../2001/Benin.txt
# 8                  ../2001/Benin.txt
# 9     ../2001/Bosnia-Herzegovina.txt
# 10    ../2001/Bosnia-Herzegovina.txt
# 11    ../2001/Bosnia-Herzegovina.txt
# 12    ../2001/Bosnia-Herzegovina.txt
# 13    ../2001/Bosnia-Herzegovina.txt
# 14                ../2001/Brazil.txt
# 15              ../2001/Bulgaria.txt
# 16          ../2001/Burkina_Faso.txt
# 17          ../2001/Burkina_Faso.txt
# 18          ../2001/Burkina_Faso.txt
# 19          ../2001/Burkina_Faso.txt
# 20          ../2001/Burkina_Faso.txt
# 21                 ../2001/Burma.txt
# 22                 ../2001/Burma.txt
# 23                 ../2001/Burma.txt
# 24              ../2001/Cambodia.txt
# 25              ../2001/Cambodia.txt
# 26              ../2001/Cambodia.txt
# 27                ../2001/Canada.txt
# 28                ../2001/Canada.txt
# 29                 ../2001/China.txt
# ...                              ...
# 7796             ../2016/Vietnam.txt
# 7797             ../2016/Vietnam.txt
# 7798             ../2016/Vietnam.txt
# 7799             ../2016/Vietnam.txt
# 7800               ../2016/Yemen.txt
# 7801               ../2016/Yemen.txt
# 7802               ../2016/Yemen.txt
# 7803               ../2016/Yemen.txt
# 7804               ../2016/Yemen.txt
# 7805               ../2016/Yemen.txt
# 7806               ../2016/Yemen.txt
# 7807               ../2016/Yemen.txt
# 7808               ../2016/Yemen.txt
# 7809               ../2016/Yemen.txt
# 7810               ../2016/Yemen.txt
# 7811              ../2016/Zambia.txt
# 7812              ../2016/Zambia.txt
# 7813              ../2016/Zambia.txt
# 7814              ../2016/Zambia.txt
# 7815              ../2016/Zambia.txt
# 7816              ../2016/Zambia.txt
# 7817            ../2016/Zimbabwe.txt
# 7818            ../2016/Zimbabwe.txt
# 7819            ../2016/Zimbabwe.txt
# 7820            ../2016/Zimbabwe.txt
# 7821            ../2016/Zimbabwe.txt
# 7822            ../2016/Zimbabwe.txt
# 7823            ../2016/Zimbabwe.txt
# 7824            ../2016/Zimbabwe.txt
# 7825            ../2016/Zimbabwe.txt
#
#                                                    text  label_x  label_y  \
# 0     TRAFFICKING VICTIMS ARE MOSTLY WOMEN FROM ALBA...      NaN      NaN
# 1     \nAUSTRIA IS A DESTINATION AND TRANSIT COUNTRY...      NaN      NaN
# 2     WORKERS FROM THE PHILIPPINES, ETHIOPIA, INDIA,...      1.0      NaN
# 3     SEVERAL THOUSAND WOMEN AND GIRLS ARE TRAFFICKE...      NaN      NaN
# 4     YOUNG WOMEN ARE TRAFFICKED THROUGH BELARUS FRO...      NaN      1.0
# 5     \nBELGIUM IS A TRANSIT AND DESTINATION COUNTRY...      NaN      NaN
# 6     VICTIMS ARE PRIMARILY YOUNG WOMEN TRAFFICKED F...      NaN      NaN
# 7     BENINESE CHILDREN ARE TRAFFICKED TO GHANA, NIG...      NaN      NaN
# 8     CHILDREN FROM NIGER, TOGO, AND BURKINA FASO HA...      NaN      1.0
# 9     \nBOSNIA IS A MAJOR DESTINATION AND TRANSIT CO...      NaN      NaN
# 10    NEITHER THE NATIONAL GOVERNMENT OF BOSNIA, NOR...      NaN      NaN
# 11    THE INTERNATIONAL ORGANIZATIONS AND THE NGO'S ...      NaN      NaN
# 12    BOSNIA HAS AN INTER-AGENCY ANTI-TRAFFICKING TA...      NaN      NaN
# 13    BOSNIA SUPPORTS NO PREVENTION OR PROTECTION ME...      NaN      NaN
# 14    THE MAJORITY OF BRAZILIAN TRAFFICKING VICTIMS ...      0.0      NaN
# 15    WOMEN FROM ROMANIA, MOLDOVA, RUSSIA, UKRAINE, ...      NaN      NaN
# 16    BURKINA FASO IS A TRANSIT COUNTRY FOR TRAFFICK...      NaN      NaN
# 17    CHILDREN IN TRANSIT FROM MALI ARE OFTEN DESTIN...      NaN      0.0
# 18    TRAFFICKED MALIAN CHILDREN ARE ALSO DESTINED F...      NaN      1.0
# 19    DESTINATIONS FOR TRAFFICKED BURKINABE CHILDREN...      NaN      NaN
# 20    IN 1999 THERE WERE REPORTS OF TRAFFICKED BURKI...      NaN      NaN
# 21    \nBURMA IS A COUNTRY OF ORIGIN FOR TRAFFICKING...      NaN      NaN
# 22    MEN AND BOYS REPORTEDLY ARE TRAFFICKED TO OTHE...      NaN      NaN
# 23    IN ADDITION TO THAILAND, BURMESE ADULTS ARE TR...      NaN      NaN
# 24    CAMBODIAN MEN, WOMEN, AND CHILDREN ARE TRAFFIC...      NaN      NaN
# 25    CAMBODIA IS A DESTINATION COUNTRY FOR YOUNG WO...      NaN      NaN
# 26    THE GOVERNMENT COOPERATES WITH THE GOVERNMENTS...      NaN      NaN
# 27    \nCANADA IS A PRIMARILY A TRANSIT AND DESTINAT...      NaN      NaN
# 28    THERE ARE ALSO ISOLATED CASES OF CANADIAN MINO...      NaN      NaN
# 29    INTERNATIONALLY, CHINESE CITIZENS ARE TRAFFICK...      NaN      NaN
# ...                                                 ...      ...      ...
# 7796  SOME VICTIMS ARE SUBJECTED TO FORCED LABOR IN ...      NaN      NaN
# 7797  VIETNAMESE WOMEN AND CHILDREN ARE SUBJECTED TO...      NaN      NaN
# 7798  SOME VIETNAMESE WOMEN WHO TRAVEL ABROAD FOR IN...      NaN      NaN
# 7799  VIETNAMESE ORGANIZED CRIME NETWORKS RECRUIT, U...      NaN      NaN
# 7800  FOR THE PURPOSES OF THIS REPORT, YEMEN HAS SPE...      NaN      NaN
# 7801  SOME YEMENI CHILDREN, MOSTLY BOYS, WERE SUBJEC...      NaN      NaN
# 7802  TRAFFICKERS, SECURITY OFFICIALS, AND EMPLOYERS...      NaN      0.0
# 7803  PRIOR TO THE ESCALATION OF THE CONFLICT AND TH...      NaN      NaN
# 7804  AN ESTIMATED 12,000 SYRIAN REFUGEES WERE IN YE...      NaN      NaN
# 7805  SYRIAN REFUGEE WOMEN AND CHILDREN BEGGING IN T...      NaN      1.0
# 7806  YEMENI CHILDREN WERE SUBJECTED TO SEX TRAFFICK...      NaN      NaN
# 7807  SOME SAUDI MEN USED LEGALLY CONTRACTED “TEMPOR...      NaN      NaN
# 7808  YEMENI AND SAUDI GANGS TRANSPORTED AFRICAN CHI...      NaN      NaN
# 7809  TRAFFICKERS ABUSED AND ABANDONED IN YEMEN SOME...      NaN      NaN
# 7810  IN PAST YEARS, MULTIPLE NGOS REPORTED CRIMINAL...      NaN      NaN
# 7811  ZAMBIAN BOYS AND GIRLS ARE EXPLOITED IN SEX TR...      NaN      NaN
# 7812  ZAMBIAN BOYS ARE SUBJECTED TO SEX TRAFFICKING ...      NaN      NaN
# 7813  NATIONALS FROM SOUTH AND EAST ASIA ARE EXPLOIT...      NaN      NaN
# 7814  CHINESE TRAFFICKERS BRING IN CHINESE WOMEN AND...      NaN      1.0
# 7815  SOUTHEAST ASIANS WHO TRANSIT ZAMBIA ARE SUBJEC...      NaN      NaN
# 7816  POTENTIAL TRAFFICKING VICTIMS FROM ETHIOPIA, D...      NaN      NaN
# 7817  WOMEN AND GIRLS FROM ZIMBABWEAN TOWNS BORDERIN...      NaN      NaN
# 7818  THERE ARE CONTINUOUS REPORTS OF ZIMBABWEAN WOM...      NaN      NaN
# 7819  THERE WERE INCREASED REPORTS OF CHILDREN FROM ...      NaN      NaN
# 7820  MANY ZIMBABWEAN ADULT AND CHILD MIGRANTS IN SO...      NaN      0.0
# 7821  SOME ZIMBABWEAN MEN, WOMEN, AND CHILDREN IN SO...      NaN      NaN
# 7822  MEN, WOMEN, AND CHILDREN, PREDOMINANTLY FROM E...      NaN      NaN
# 7823  REFUGEES FROM SOMALIA AND DEMOCRATIC REPUBLIC ...      NaN      NaN
# 7824  CHINESE NATIONALS ARE REPORTEDLY FORCED TO LAB...      NaN      NaN
# 7825  CHINESE CONSTRUCTION AND MINING COMPANIES REPO...      NaN      NaN
#
#       label
# 0       NaN
# 1       NaN
# 2       1.0
# 3       NaN
# 4       NaN
# 5       NaN
# 6       NaN
# 7       NaN
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13      NaN
# 14      0.0
# 15      NaN
# 16      NaN
# 17      NaN
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22      NaN
# 23      NaN
# 24      NaN
# 25      NaN
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# ...     ...
# 7796    NaN
# 7797    NaN
# 7798    NaN
# 7799    NaN
# 7800    NaN
# 7801    NaN
# 7802    NaN
# 7803    NaN
# 7804    NaN
# 7805    NaN
# 7806    NaN
# 7807    NaN
# 7808    NaN
# 7809    NaN
# 7810    NaN
# 7811    NaN
# 7812    NaN
# 7813    NaN
# 7814    NaN
# 7815    NaN
# 7816    NaN
# 7817    NaN
# 7818    NaN
# 7819    NaN
# 7820    NaN
# 7821    NaN
# 7822    NaN
# 7823    NaN
# 7824    NaN
# 7825    NaN
#
# [7826 rows x 8 columns]

# %%
# Fix up the names for a couple of countries incorrectly parsed
combined = combined.loc[combined['file']!= '../2009/St._Vincent_And_The_Grenadines.txt']
combined.loc[combined['file'].str.contains('2009/Sri_Lanka.txt') & combined['countries'].str.contains('SUDAN|CHAD'), 'country'] = 'SUDAN'
combined = combined.drop(combined.loc[((combined['file']=='../2009/Sri_Lanka.txt') & (combined['countries']=='SUDAN'))].index)
combined.shape
# Out:
# /Users/christopher/anaconda/envs/py36/lib/python3.6/site-packages/pandas/core/indexing.py:517: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# (7788, 8)

# %%
combined = combined.drop(combined.loc[combined['text'].str.contains('AMERICAN INDIAN')].index)

# %%
combined.loc[combined.label_y == 1, 'label'] = 1

# %%
unlabelled = combined[(combined.label != 1) & (combined.label != 0)]
labelled = combined[(combined.label == 1) | (combined.label == 0)] 
labelled.shape, unlabelled.shape
# Out:
# ((2096, 8), (5685, 8))

# %%
labelled
train, test = train_test_split(labelled, test_size=0.2, random_state=1253)

# %%
X_test = test['text']
y_test = np.array(test[['label']].values.flatten(), dtype="int")

X_train = train['text']
y_train = np.array(train[['label']].values.flatten(), dtype="int")

count_vect = CountVectorizer(decode_error='ignore', ngram_range=(1,2))
tfidf_transformer = TfidfTransformer()
X_train_counts = count_vect.fit_transform(X_train)
X_train_tfidf = tfidf_transformer.fit_transform(X_train_counts)

print("There are {:,} words in the vocabulary.".format(len(count_vect.vocabulary_)))
print(X_train_counts.shape)
print(X_train_tfidf.shape)
print(len(X_train))
print(Counter(y_train))

X_test_counts = count_vect.transform(X_test)
X_test_tfidf = tfidf_transformer.transform(X_test_counts)

print(X_test_counts.shape)
print(X_test_tfidf.shape)
print(len(X_test))
print(Counter(y_test))
# Out:
# There are 17,093 words in the vocabulary.
# (1676, 17093)
# (1676, 17093)
# 1676
# Counter({1: 915, 0: 761})
# (420, 17093)
# (420, 17093)
# 420
# Counter({1: 249, 0: 171})

# %%
y_train = np.array(y_train,dtype='int')
y_train
# Out:
# array([1, 0, 1, ..., 1, 0, 0])

# %%
X_unlabelled_counts = count_vect.transform(unlabelled['text'])
print(X_unlabelled_counts.shape)
# Out:
# (5685, 17093)

# %% [markdown]
# ### Estimate classification models

# %%
kf = KFold(n_splits=10, shuffle=True, random_state=1213)
f1_scorer = make_scorer(f1_score)
print(f1_scorer)
# Out:
# make_scorer(f1_score)

# %%
#logistic regression
grid = {
        'C': [1, .9, .8, .7, .6, .5, .25, .1],
        'penalty' : ['l1', 'l2']
    }
logit = LogisticRegression()
loggs = GridSearchCV(logit, grid, scoring=f1_scorer, cv=kf, n_jobs=-1)
loggs.fit(X_train_counts, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1213, shuffle=True),
#        error_score='raise',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': [1, 0.9, 0.8, 0.7, 0.6, 0.5, 0.25, 0.1], 'penalty': ['l1', 'l2']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(f1_score), verbose=0)

# %%
#multinomial naive bayes with counts
grid = {
        'alpha': [1, .8,.6, .5, .4, .2]
    }
mnb = MultinomialNB()
mnbgs = GridSearchCV(mnb, grid, scoring=f1_scorer, cv=kf)
mnbgs.fit(X_train_counts, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1213, shuffle=True),
#        error_score='raise',
#        estimator=MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True),
#        fit_params={}, iid=True, n_jobs=1,
#        param_grid={'alpha': [1, 0.8, 0.6, 0.5, 0.4, 0.2]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(f1_score), verbose=0)

# %%
#SVM with counts
grid = {
        'C': [1, .9, .8, .7, .6, .5]
    }
svc = SVC(kernel='linear', probability=True)
svcgs = GridSearchCV(svc, grid, scoring=f1_scorer, cv=kf, n_jobs=-1)
svcgs.fit(X_train_counts, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1213, shuffle=True),
#        error_score='raise',
#        estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape=None, degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=True, random_state=None, shrinking=True,
#   tol=0.001, verbose=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'C': [1, 0.9, 0.8, 0.7, 0.6, 0.5]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=make_scorer(f1_score), verbose=0)

# %%
# Random forest
grid = { "n_estimators"      : [1000, 1500, 2000],
           "max_depth"         : [10, 25, 50] }
rf = RandomForestClassifier()
rfgs = GridSearchCV(rf, grid, n_jobs=-1, cv=kf)
rfgs.fit(X_train_counts, y_train)
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=1213, shuffle=True),
#        error_score='raise',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_split=1e-07, min_samples_leaf=1,
#             min_samples_split=2, min_weight_fraction_leaf=0.0,
#             n_estimators=10, n_jobs=1, oob_score=False, random_state=None,
#             verbose=0, warm_start=False),
#        fit_params={}, iid=True, n_jobs=-1,
#        param_grid={'n_estimators': [1000, 1500, 2000], 'max_depth': [10, 25, 50]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#        scoring=None, verbose=0)

# %%
logpreds = loggs.predict(X_test_counts)
svcpreds = svcgs.predict(X_test_counts)
mnbpreds = mnbgs.predict(X_test_counts)
rfpreds = rfgs.predict(X_test_counts)

# %%
unlabpreds = loggs.predict(X_unlabelled_counts)
unlabelled['label'] = unlabpreds
# Out:
# /Users/christopher/anaconda/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
final = pd.concat([labelled, unlabelled], axis=0)

# %%
year = '\d{4}' 
final['year'] = final.file.str.extract('('+year+')', expand=False)
final
# Out:
#                                               countries             country  \
# 2     RUSSIAN FEDERATION;ETHIOPIA;PHILIPPINES;BELARU...             BAHRAIN
# 4     UKRAINE;GERMANY;POLAND;LITHUANIA;RUSSIAN FEDER...             BELARUS
# 8                               TOGO;NIGER;BURKINA FASO               BENIN
# 14                JAPAN;ISRAEL;UNITED STATES OF AMERICA              BRAZIL
# 18                                                 MALI        BURKINA FASO
# 31    NETHERLANDS;SINGAPORE;UNITED STATES OF AMERICA...            COLOMBIA
# 33                                          PHILIPPINES          COSTA RICA
# 40    ISRAEL;NETHERLANDS;ITALY;CURACAO;ARUBA;BELGIUM...  DOMINICAN REPUBLIC
# 44                                           TOGO;BENIN               GABON
# 48                           TOGO;NIGERIA;COTE D'IVOIRE               GHANA
# 54                                               CANADA            HONDURAS
# 55                                    PHILIPPINES;CHINA           HONG KONG
# 56                                            INDONESIA           HONG KONG
# 57                                              VIETNAM           HONG KONG
# 60                                     NEPAL;BANGLADESH               INDIA
# 55             ../2001/Hong_Kong.txt
# 56             ../2001/Hong_Kong.txt
# 57             ../2001/Hong_Kong.txt
# 60                 ../2001/India.txt
# 63             ../2001/Indonesia.txt
# 64             ../2001/Indonesia.txt
# 65                ../2001/Israel.txt
# 67                 ../2001/Japan.txt
# 68                 ../2001/Japan.txt
# 73                  ../2001/Laos.txt
# 74                  ../2001/Laos.txt
# 75               ../2001/Lebanon.txt
# 76               ../2001/Lebanon.txt
# 87                 ../2001/Nepal.txt
# 88                 ../2001/Nepal.txt
# 98                 ../2001/Qatar.txt
# 101         ../2001/Saudi_Arabia.txt
# 102            ../2001/Singapore.txt
# 103            ../2001/Singapore.txt
# ...                              ...
# 7794           ../2016/Venezuela.txt
# 7795           ../2016/Venezuela.txt
# 7796             ../2016/Vietnam.txt
# 7797             ../2016/Vietnam.txt
# 7798             ../2016/Vietnam.txt
# 7799             ../2016/Vietnam.txt
# 7800               ../2016/Yemen.txt
# 7801               ../2016/Yemen.txt
# 7802               ../2016/Yemen.txt
# 7803               ../2016/Yemen.txt
# 7804               ../2016/Yemen.txt
# 7806               ../2016/Yemen.txt
# 7807               ../2016/Yemen.txt
# 7808               ../2016/Yemen.txt
# 7809               ../2016/Yemen.txt
# 7810               ../2016/Yemen.txt
# 7811              ../2016/Zambia.txt
# 7812              ../2016/Zambia.txt
# 7813              ../2016/Zambia.txt
# 7815              ../2016/Zambia.txt
# 7816              ../2016/Zambia.txt
# 7817            ../2016/Zimbabwe.txt
# 7818            ../2016/Zimbabwe.txt
# 7819            ../2016/Zimbabwe.txt
# 7820            ../2016/Zimbabwe.txt
# 7821            ../2016/Zimbabwe.txt
# 7822            ../2016/Zimbabwe.txt
# 7823            ../2016/Zimbabwe.txt
# 7824            ../2016/Zimbabwe.txt
# 7825            ../2016/Zimbabwe.txt
#
#                                                    text  label_x  label_y  \
# 2     WORKERS FROM THE PHILIPPINES, ETHIOPIA, INDIA,...      1.0      NaN
# 4     YOUNG WOMEN ARE TRAFFICKED THROUGH BELARUS FRO...      NaN      1.0
# 8     CHILDREN FROM NIGER, TOGO, AND BURKINA FASO HA...      NaN      1.0
# 14    THE MAJORITY OF BRAZILIAN TRAFFICKING VICTIMS ...      0.0      NaN
# 18    TRAFFICKED MALIAN CHILDREN ARE ALSO DESTINED F...      NaN      1.0
# 31    \nCOLOMBIA IS A SOURCE COUNTRY FOR TRAFFICKED ...      0.0      NaN
# 33    THERE ALSO HAVE BEEN REPORTS OF GIRLS FROM THE...      NaN      1.0
# 40    ACCORDING TO THE CENTER FOR INTEGRAL ORIENTATI...      0.0      NaN
# 44    \nGABON IS A DESTINATION COUNTRY FOR TRAFFICKE...      1.0      NaN
# 48    CHILDREN ARE TRAFFICKED TO AND FROM COTE D'IVO...      NaN      1.0
# 54    HONDURAN BOYS REPORTEDLY ARE BEING TRAFFICKED ...      0.0      NaN
# 55    ABOUT THREE-FOURTHS ARE FROM ELSEWHERE IN CHIN...      NaN      1.0
# 56    SOME FOREIGN DOMESTIC WORKERS, PARTICULARLY FR...      NaN      1.0
# 57    THERE HAVE ALSO BEEN REPORTS THAT SOME WOMEN F...      NaN      1.0
# 60    INDIA IS A DESTINATION COUNTRY FOR NEPALI AND ...      NaN      1.0
# 63    INDONESIANS ARE TRAFFICKED TO HONG KONG, SINGA...      0.0      NaN
# 64    INDONESIA IS ALSO A TRANSIT COUNTRY FOR ALIEN ...      0.0      NaN
# 65    WOMEN ARE TRAFFICKED TO ISRAEL FROM THE NEW IN...      1.0      NaN
# 67    \nJAPAN IS A DESTINATION COUNTRY FOR WOMEN, PR...      1.0      NaN
# 68    JAPAN IS ALSO A DESTINATION POINT FOR ILLEGAL ...      1.0      NaN
# 73    NEARLY ALL ARE TRAFFICKED TO THAILAND, ALTHOUG...      0.0      NaN
# 74    AN ESTIMATED 20,000 LAO ENTER THAILAND ANNUALL...      0.0      NaN
# 75    WOMEN FROM ETHIOPIA TRAVEL TO LEBANON, IN THE ...      1.0      NaN
# 76    WOMEN FROM THE NEW INDEPENDENT STATES (SPECIFI...      1.0      NaN
# 87    POOR, UNEDUCATED YOUNG WOMEN FROM NEPAL'S RURA...      0.0      NaN
# 88    NEPALESE CITIZENS ALSO ARE TRAFFICKED TO HONG ...      0.0      NaN
# 98    BOYS ARE TRAFFICKED FROM PAKISTAN AND BANGLADE...      1.0      NaN
# 101   WORKERS FROM BANGLADESH, THAILAND, INDIA, THE ...      1.0      NaN
# 102   \nSINGAPORE IS A DESTINATION COUNTRY FOR WOMEN...      1.0      NaN
# 103   INDIAN, BANGLADESHI, AND FILIPINO MEN AND WOME...      1.0      NaN
# ...                                                 ...      ...      ...
# 7794  NGOS CONTINUE TO REPORT VENEZUELAN WOMEN ARE S...      NaN      NaN
# 7795  MEDIA REPORTS INDICATE SOME OF THE ESTIMATED 3...      NaN      NaN
# 7796  SOME VICTIMS ARE SUBJECTED TO FORCED LABOR IN ...      NaN      NaN
# 7797  VIETNAMESE WOMEN AND CHILDREN ARE SUBJECTED TO...      NaN      NaN
# 7798  SOME VIETNAMESE WOMEN WHO TRAVEL ABROAD FOR IN...      NaN      NaN
# 7799  VIETNAMESE ORGANIZED CRIME NETWORKS RECRUIT, U...      NaN      NaN
# 7800  FOR THE PURPOSES OF THIS REPORT, YEMEN HAS SPE...      NaN      NaN
# 7801  SOME YEMENI CHILDREN, MOSTLY BOYS, WERE SUBJEC...      NaN      NaN
# 7802  TRAFFICKERS, SECURITY OFFICIALS, AND EMPLOYERS...      NaN      0.0
# 7803  PRIOR TO THE ESCALATION OF THE CONFLICT AND TH...      NaN      NaN
# 7804  AN ESTIMATED 12,000 SYRIAN REFUGEES WERE IN YE...      NaN      NaN
# 7806  YEMENI CHILDREN WERE SUBJECTED TO SEX TRAFFICK...      NaN      NaN
# 7807  SOME SAUDI MEN USED LEGALLY CONTRACTED “TEMPOR...      NaN      NaN
# 7808  YEMENI AND SAUDI GANGS TRANSPORTED AFRICAN CHI...      NaN      NaN
# 7809  TRAFFICKERS ABUSED AND ABANDONED IN YEMEN SOME...      NaN      NaN
# 7810  IN PAST YEARS, MULTIPLE NGOS REPORTED CRIMINAL...      NaN      NaN
# 7811  ZAMBIAN BOYS AND GIRLS ARE EXPLOITED IN SEX TR...      NaN      NaN
# 7812  ZAMBIAN BOYS ARE SUBJECTED TO SEX TRAFFICKING ...      NaN      NaN
# 7813  NATIONALS FROM SOUTH AND EAST ASIA ARE EXPLOIT...      NaN      NaN
# 7815  SOUTHEAST ASIANS WHO TRANSIT ZAMBIA ARE SUBJEC...      NaN      NaN
# 7816  POTENTIAL TRAFFICKING VICTIMS FROM ETHIOPIA, D...      NaN      NaN
# 7817  WOMEN AND GIRLS FROM ZIMBABWEAN TOWNS BORDERIN...      NaN      NaN
# 7818  THERE ARE CONTINUOUS REPORTS OF ZIMBABWEAN WOM...      NaN      NaN
# 7819  THERE WERE INCREASED REPORTS OF CHILDREN FROM ...      NaN      NaN
# 7820  MANY ZIMBABWEAN ADULT AND CHILD MIGRANTS IN SO...      NaN      0.0
# 7821  SOME ZIMBABWEAN MEN, WOMEN, AND CHILDREN IN SO...      NaN      NaN
# 7822  MEN, WOMEN, AND CHILDREN, PREDOMINANTLY FROM E...      NaN      NaN
# 7823  REFUGEES FROM SOMALIA AND DEMOCRATIC REPUBLIC ...      NaN      NaN
# 7824  CHINESE NATIONALS ARE REPORTEDLY FORCED TO LAB...      NaN      NaN
# 7825  CHINESE CONSTRUCTION AND MINING COMPANIES REPO...      NaN      NaN
#
#       label  year
# 2       1.0  2001
# 4       1.0  2001
# 8       1.0  2001
# 14      0.0  2001
# 18      1.0  2001
# 31      0.0  2001
# 33      1.0  2001
# 40      0.0  2001
# 44      1.0  2001
# 48      1.0  2001
# 54      0.0  2001
# 55      1.0  2001
# 56      1.0  2001
# 57      1.0  2001
# 60      1.0  2001
# 63      0.0  2001
# 64      0.0  2001
# 65      1.0  2001
# 67      1.0  2001
# 68      1.0  2001
# 73      0.0  2001
# 74      0.0  2001
# 75      1.0  2001
# 76      1.0  2001
# 87      0.0  2001
# 88      0.0  2001
# 98      1.0  2001
# 101     1.0  2001
# 102     1.0  2001
# 103     1.0  2001
# ...     ...   ...
# 7794    1.0  2016
# 7795    0.0  2016
# 7796    0.0  2016
# 7797    0.0  2016
# 7798    0.0  2016
# 7799    0.0  2016
# 7800    0.0  2016
# 7801    0.0  2016
# 7802    1.0  2016
# 7803    1.0  2016
# 7804    1.0  2016
# 7806    0.0  2016
# 7807    1.0  2016
# 7808    1.0  2016
# 7809    1.0  2016
# 7810    1.0  2016
# 7811    0.0  2016
# 7812    0.0  2016
# 7813    1.0  2016
# 7815    0.0  2016
# 7816    0.0  2016
# 7817    1.0  2016
# 7818    1.0  2016
# 7819    1.0  2016
# 7820    0.0  2016
# 7821    0.0  2016
# 7822    1.0  2016
# 7823    1.0  2016
# 7824    1.0  2016
# 7825    1.0  2016
#
# [7781 rows x 9 columns]

# %% [markdown]
# ### Save predicted classes for country pairs

# %%
final = final[['year', 'country', 'countries', 'text', 'label']]
final.to_csv('../relation_extracction/final_classifier_upload.csv', index=False)
